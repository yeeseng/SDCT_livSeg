# %%
import os
import random
import matplotlib.pyplot as plt
import pylab
import numpy as np

# %%
import keras
from keras.models import Model
from keras import models
from keras.layers import *
from keras.optimizers import Adam
from keras.optimizers import RMSprop
from keras.optimizers import SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
from keras.callbacks import TensorBoard
from keras.callbacks import LearningRateScheduler, ModelCheckpoint

SEED = 243
random.seed(SEED)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load prepared data from folder
# prepared from MADplot-AdvUNETS1-prepareData

# %%
x_train = np.load('excldCV5-data/MADplot_xTrain_All_images.npy')
y_train = np.load('excldCV5-data/MADplot_yTrain_All_images.npy')
x_val = np.load('excldCV5-data/MADplot_xVal_All_images.npy')
y_val = np.load('excldCV5-data/MADplot_yVal_All_images.npy')

# %%
print (x_train.shape)
print (y_train.shape)
#y_train.astype('float32')
print (x_val.shape)
print (y_val.shape)
#y_val.astype('float32')
# Out:
# (852, 512, 512, 2)
# (852, 512, 512, 1)
# (198, 512, 512, 2)
# (198, 512, 512, 1)

# %%
count =  sum(sum(sum(y_train)))
total = 852*512*512
w2 = float(count/total)
w1 = 1-w2

weights = [w2, w1]
print(weights)
# Out:
# [0.06115531473652298, 0.938844685263477]

# %%
# Another sanity check
print (x_train[:,:,:,0].mean())
print (x_train[:,:,:,1].mean())
print (x_val[:,:,:,0].mean())
print (x_val[:,:,:,1].mean())
# Out:
# 902.9299
# 545.27484
# 878.41626
# 535.3294

# %%
# Test a few data for sanity check
fig, ax = plt.subplots(1,3, figsize = (12,4))
ax[0].imshow(x_train[55,:,:,0].T, cmap='gray')
ax[1].imshow(x_train[55,:,:,1].T, cmap='gray')
ax[2].imshow(y_train[55,:,:,0].T, cmap='gray')
plt.show()

# %%
# Code is here for initial training. Note that custom metrics is not compatible for saving and loading
#def dice_coef(y_true, y_pred):
#    y_true_f = K.flatten(y_true)
#    y_pred_f = K.flatten(y_pred)
#    intersection = K.sum(y_true_f * y_pred_f)
#    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %% [markdown]
# Create image generators for training and validation sets

# %%
def my_generator(x_data, y_data, batch_size):
    data_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(x_data, x_data, batch_size, seed=SEED)
    mask_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(y_data, y_data, batch_size, seed=SEED)
    while True:
        x_batch, _ = data_generator.next()
        y_batch, _ = mask_generator.next()
        yield x_batch, y_batch

# %%
train_gen = my_generator(x_train, y_train, 4)

# %%
val_gen = ImageDataGenerator().flow(x_val, y_val, batch_size=4, seed=SEED)
# Out:
# /home/yeeseng/anaconda3/envs/DLenv/lib/python3.6/site-packages/keras_preprocessing/image.py:1643: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (198, 512, 512, 2) (2 channels).
#   str(self.x.shape[channels_axis]) + ' channels).')

# %%
image_batch, mask_batch = next(my_generator(x_train, y_train, 4))
fix, ax = plt.subplots(2,3, figsize=(12,10))
for i in range(2):
    ax[i,0].imshow(image_batch[i,:,:,0])
    ax[i,1].imshow(image_batch[i,:,:,1])
    ax[i,2].imshow(mask_batch[i,:,:,0])
plt.show()

sum(sum(mask_batch[1,:,:,0]))
# Out:
# /home/yeeseng/anaconda3/envs/DLenv/lib/python3.6/site-packages/keras_preprocessing/image.py:1643: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (852, 512, 512, 2) (2 channels).
#   str(self.x.shape[channels_axis]) + ' channels).')
# 25950.051597595215

# %% [markdown]
# # UNET architecture

# %%
def unet(pretrained_weights = None,input_size = (512,512,2)):
    
    initializerString = 'TruncatedNormal'
    
    inputs = Input(input_size)
    #norm1 = BatchNormalization(axis=-1)(inputs)
    
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv4)
    drop4 = Dropout(0.3)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(pool4)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv5)
    drop5 = Dropout(0.3)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = -1)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = -1)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = -1)
    #merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = -1)
    #merge9 = merge([conv1,up9], mode = 'concat', concat_axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = initializerString)(conv9)
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    
    model = Model(inputs = inputs, outputs = conv10)

    if(pretrained_weights):
    	model.load_weights(pretrained_weights)

    return model

# %%
model = unet(input_size = image_batch[1].shape)

# %%
model.compile(optimizer = Adam(lr=5e-7), loss = 'binary_crossentropy', metrics = ['binary_accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 512, 512, 2)  0
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 512, 512, 64) 1216        input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 512, 512, 64) 36928       conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 256, 256, 64) 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 256, 128 73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 128 147584      conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 128 0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 128, 128, 256 295168      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 256 590080      conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 256)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 512)  1180160     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 512)  2359808     conv2d_32[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 512)  0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 512)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 1024) 4719616     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 1024) 9438208     conv2d_34[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 1024) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 1024) 0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 512)  2097664     up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 1024) 0           dropout_3[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 512)  4719104     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 512)  2359808     conv2d_37[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 512 0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 256 524544      up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 512 0           conv2d_31[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 256 1179904     concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 256 590080      conv2d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 256 0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 256, 256, 128 131200      up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 256 0           conv2d_29[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 256, 256, 128 295040      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 256, 256, 128 147584      conv2d_43[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 512, 512, 128 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 512, 512, 64) 32832       up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 512, 512, 128 0           conv2d_27[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 512, 512, 64) 73792       concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 512, 512, 64) 36928       conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 512, 512, 2)  1154        conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 512, 512, 1)  3           conv2d_48[0][0]
# ==================================================================================================
# Total params: 31,032,261
# Trainable params: 31,032,261
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# or if model is already saved, load model from h5 file

# %%
#model = models.load_model('MADplot-AdvUNETS-Data/180805_MADplot-UNETS_19-0.997.h5')

# %%
from datetime import date
datestring = date.today().strftime("%y%m%d")

#weight_saver = ModelCheckpoint('MADplot-AdvUNETS-Data/' +datestring + '_MADplot-UNETS_{epoch:02d}-{val_binary_accuracy:.05f}.h5', monitor='binary_accuracy', save_best_only=True, save_weights_only=False)
#tensor_board = TensorBoard('./logs/'+datestring+'MADplot_AdvUNETS_simple1')
#annealer = LearningRateScheduler(lambda x: 1e-3 * 0.8 ** x)

# %%
## Import up sound alert dependencies
from IPython.display import Audio, display

def allDone():
  display(Audio(url='http://www.kozco.com/tech/piano2.wav', autoplay=True))
## Insert whatever audio file you want above

allDone()
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="http://www.kozco.com/tech/piano2.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#from sklearn.utils import class_weight

#k = [1, 0, 3, 2, 5, 0, 0, 0, 1]

#class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(k),
                                                 k)
#print(class_weights)
#model.fit(X_train, y_train, class_weight=class_weights)

# %%
K.tensorflow_backend._get_available_gpus()
import tensorflow as tf
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
sess = K.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
import time
start = time.time()
print (start)

#class_weights = [0.022, 0.978]

hist = model.fit_generator(train_gen,
                           steps_per_epoch = 852*2,
                           validation_data = val_gen,
                           epochs=100,
                          callbacks = [],
                          validation_steps = int(198/2),
                          class_weight=weights)
    #savePath = 'MADplot-AdvUNETS-Data/liverSegUNETS_' + str(i+51) + '.h5'
    #model.save(savePath)

end = time.time()
print (end)
print(end - start)
    
allDone()
# Out:
# 1553899292.4713223
# Epoch 1/100
# 1704/1704 [==============================] - 950s 558ms/step - loss: 0.7574 - binary_accuracy: 0.9187 - val_loss: 0.2861 - val_binary_accuracy: 0.9411
# Epoch 2/100
# 1704/1704 [==============================] - 942s 553ms/step - loss: 0.2506 - binary_accuracy: 0.9369 - val_loss: 0.2306 - val_binary_accuracy: 0.9414
# Epoch 3/100
# 1704/1704 [==============================] - 943s 554ms/step - loss: 0.2253 - binary_accuracy: 0.9371 - val_loss: 0.2115 - val_binary_accuracy: 0.9412
# Epoch 4/100
# 1704/1704 [==============================] - 944s 554ms/step - loss: 0.2073 - binary_accuracy: 0.9370 - val_loss: 0.2041 - val_binary_accuracy: 0.9421
# Epoch 5/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1901 - binary_accuracy: 0.9371 - val_loss: 0.1720 - val_binary_accuracy: 0.9422
# Epoch 6/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1761 - binary_accuracy: 0.9371 - val_loss: 0.1682 - val_binary_accuracy: 0.9409
# Epoch 7/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1647 - binary_accuracy: 0.9369 - val_loss: 0.1443 - val_binary_accuracy: 0.9409
# Epoch 8/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1552 - binary_accuracy: 0.9372 - val_loss: 0.1482 - val_binary_accuracy: 0.9422
# Epoch 9/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1480 - binary_accuracy: 0.9372 - val_loss: 0.1483 - val_binary_accuracy: 0.9409
# Epoch 10/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1421 - binary_accuracy: 0.9371 - val_loss: 0.1174 - val_binary_accuracy: 0.9422
# Epoch 11/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1365 - binary_accuracy: 0.9370 - val_loss: 0.1181 - val_binary_accuracy: 0.9412
# Epoch 12/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1320 - binary_accuracy: 0.9372 - val_loss: 0.1073 - val_binary_accuracy: 0.9410
# Epoch 13/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1270 - binary_accuracy: 0.9371 - val_loss: 0.1206 - val_binary_accuracy: 0.9423
# Epoch 14/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1240 - binary_accuracy: 0.9371 - val_loss: 0.0966 - val_binary_accuracy: 0.9409
# Epoch 15/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1204 - binary_accuracy: 0.9370 - val_loss: 0.1008 - val_binary_accuracy: 0.9418
# Epoch 16/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1165 - binary_accuracy: 0.9368 - val_loss: 0.0926 - val_binary_accuracy: 0.9398
# Epoch 17/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1138 - binary_accuracy: 0.9370 - val_loss: 0.0970 - val_binary_accuracy: 0.9452
# Epoch 18/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1108 - binary_accuracy: 0.9371 - val_loss: 0.0927 - val_binary_accuracy: 0.9403
# Epoch 19/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1086 - binary_accuracy: 0.9370 - val_loss: 0.0937 - val_binary_accuracy: 0.9393
# Epoch 20/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1063 - binary_accuracy: 0.9370 - val_loss: 0.0946 - val_binary_accuracy: 0.9415
# Epoch 21/100
# 1704/1704 [==============================] - 946s 555ms/step - loss: 0.1043 - binary_accuracy: 0.9371 - val_loss: 0.0913 - val_binary_accuracy: 0.9429
# Epoch 22/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1022 - binary_accuracy: 0.9371 - val_loss: 0.0942 - val_binary_accuracy: 0.9405
# Epoch 23/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.1006 - binary_accuracy: 0.9371 - val_loss: 0.1232 - val_binary_accuracy: 0.9427
# Epoch 24/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0995 - binary_accuracy: 0.9370 - val_loss: 0.0808 - val_binary_accuracy: 0.9428
# Epoch 25/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0968 - binary_accuracy: 0.9371 - val_loss: 0.1137 - val_binary_accuracy: 0.9395
# Epoch 26/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0953 - binary_accuracy: 0.9371 - val_loss: 0.0854 - val_binary_accuracy: 0.9402
# Epoch 27/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0948 - binary_accuracy: 0.9372 - val_loss: 0.0946 - val_binary_accuracy: 0.9415
# Epoch 28/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0937 - binary_accuracy: 0.9370 - val_loss: 0.0847 - val_binary_accuracy: 0.9424
# Epoch 29/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0919 - binary_accuracy: 0.9371 - val_loss: 0.0885 - val_binary_accuracy: 0.9419
# Epoch 30/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0908 - binary_accuracy: 0.9372 - val_loss: 0.0997 - val_binary_accuracy: 0.9422
# Epoch 31/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0899 - binary_accuracy: 0.9370 - val_loss: 0.0866 - val_binary_accuracy: 0.9406
# Epoch 32/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0888 - binary_accuracy: 0.9371 - val_loss: 0.0849 - val_binary_accuracy: 0.9414
# Epoch 33/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0883 - binary_accuracy: 0.9371 - val_loss: 0.0914 - val_binary_accuracy: 0.9422
# Epoch 34/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0881 - binary_accuracy: 0.9370 - val_loss: 0.0828 - val_binary_accuracy: 0.9413
# Epoch 35/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0867 - binary_accuracy: 0.9370 - val_loss: 0.0923 - val_binary_accuracy: 0.9416
# Epoch 36/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0860 - binary_accuracy: 0.9370 - val_loss: 0.0832 - val_binary_accuracy: 0.9420
# Epoch 37/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0855 - binary_accuracy: 0.9370 - val_loss: 0.0885 - val_binary_accuracy: 0.9411
# Epoch 38/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0853 - binary_accuracy: 0.9369 - val_loss: 0.1062 - val_binary_accuracy: 0.9408
# Epoch 39/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0847 - binary_accuracy: 0.9370 - val_loss: 0.0787 - val_binary_accuracy: 0.9415
# Epoch 40/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0846 - binary_accuracy: 0.9370 - val_loss: 0.0839 - val_binary_accuracy: 0.9424
# Epoch 41/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0831 - binary_accuracy: 0.9370 - val_loss: 0.0785 - val_binary_accuracy: 0.9411
# Epoch 42/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0829 - binary_accuracy: 0.9369 - val_loss: 0.0761 - val_binary_accuracy: 0.9419
# Epoch 43/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0819 - binary_accuracy: 0.9372 - val_loss: 0.0804 - val_binary_accuracy: 0.9406
# Epoch 44/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0814 - binary_accuracy: 0.9371 - val_loss: 0.0948 - val_binary_accuracy: 0.9412
# Epoch 45/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0811 - binary_accuracy: 0.9372 - val_loss: 0.0849 - val_binary_accuracy: 0.9419
# Epoch 46/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0807 - binary_accuracy: 0.9370 - val_loss: 0.0830 - val_binary_accuracy: 0.9421
# Epoch 47/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0804 - binary_accuracy: 0.9370 - val_loss: 0.0908 - val_binary_accuracy: 0.9412
# Epoch 48/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0798 - binary_accuracy: 0.9477 - val_loss: 0.0826 - val_binary_accuracy: 0.9729
# Epoch 49/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0790 - binary_accuracy: 0.9595 - val_loss: 0.0748 - val_binary_accuracy: 0.9636
# Epoch 50/100
# 1704/1704 [==============================] - 945s 555ms/step - loss: 0.0792 - binary_accuracy: 0.9598 - val_loss: 0.0993 - val_binary_accuracy: 0.9786
# Epoch 51/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0784 - binary_accuracy: 0.9602 - val_loss: 0.0887 - val_binary_accuracy: 0.9762
# Epoch 52/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0781 - binary_accuracy: 0.9610 - val_loss: 0.0790 - val_binary_accuracy: 0.9720
# Epoch 53/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0778 - binary_accuracy: 0.9606 - val_loss: 0.0768 - val_binary_accuracy: 0.9720
# Epoch 54/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0774 - binary_accuracy: 0.9613 - val_loss: 0.0809 - val_binary_accuracy: 0.9722
# Epoch 55/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0771 - binary_accuracy: 0.9617 - val_loss: 0.0809 - val_binary_accuracy: 0.9738
# Epoch 56/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0765 - binary_accuracy: 0.9622 - val_loss: 0.0780 - val_binary_accuracy: 0.9703
# Epoch 57/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0764 - binary_accuracy: 0.9627 - val_loss: 0.0739 - val_binary_accuracy: 0.9690
# Epoch 58/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0758 - binary_accuracy: 0.9632 - val_loss: 0.0767 - val_binary_accuracy: 0.9732
# Epoch 59/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0760 - binary_accuracy: 0.9628 - val_loss: 0.0851 - val_binary_accuracy: 0.9741
# Epoch 60/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0755 - binary_accuracy: 0.9632 - val_loss: 0.0765 - val_binary_accuracy: 0.9728
# Epoch 61/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0746 - binary_accuracy: 0.9645 - val_loss: 0.0766 - val_binary_accuracy: 0.9738
# Epoch 62/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0744 - binary_accuracy: 0.9645 - val_loss: 0.0885 - val_binary_accuracy: 0.9321
# Epoch 63/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0745 - binary_accuracy: 0.9642 - val_loss: 0.0744 - val_binary_accuracy: 0.9689
# Epoch 64/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0741 - binary_accuracy: 0.9644 - val_loss: 0.0748 - val_binary_accuracy: 0.9728
# Epoch 65/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0739 - binary_accuracy: 0.9652 - val_loss: 0.0746 - val_binary_accuracy: 0.9706
# Epoch 66/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0733 - binary_accuracy: 0.9658 - val_loss: 0.0708 - val_binary_accuracy: 0.9672
# Epoch 67/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0740 - binary_accuracy: 0.9646 - val_loss: 0.0768 - val_binary_accuracy: 0.9752
# Epoch 68/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0730 - binary_accuracy: 0.9655 - val_loss: 0.0864 - val_binary_accuracy: 0.9810
# Epoch 69/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0727 - binary_accuracy: 0.9662 - val_loss: 0.0782 - val_binary_accuracy: 0.9753
# Epoch 70/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0726 - binary_accuracy: 0.9665 - val_loss: 0.0730 - val_binary_accuracy: 0.9692
# Epoch 71/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0719 - binary_accuracy: 0.9671 - val_loss: 0.0711 - val_binary_accuracy: 0.9697
# Epoch 72/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0715 - binary_accuracy: 0.9675 - val_loss: 0.0773 - val_binary_accuracy: 0.9767
# Epoch 73/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0715 - binary_accuracy: 0.9672 - val_loss: 0.0757 - val_binary_accuracy: 0.9515
# Epoch 74/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0712 - binary_accuracy: 0.9676 - val_loss: 0.0838 - val_binary_accuracy: 0.9791
# Epoch 75/100
# 1704/1704 [==============================] - 939s 551ms/step - loss: 0.0713 - binary_accuracy: 0.9675 - val_loss: 0.0745 - val_binary_accuracy: 0.9754
# Epoch 76/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0706 - binary_accuracy: 0.9685 - val_loss: 0.0744 - val_binary_accuracy: 0.9755
# Epoch 77/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0706 - binary_accuracy: 0.9684 - val_loss: 0.0707 - val_binary_accuracy: 0.9656
# Epoch 78/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0702 - binary_accuracy: 0.9688 - val_loss: 0.0695 - val_binary_accuracy: 0.9665
# Epoch 79/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0704 - binary_accuracy: 0.9681 - val_loss: 0.0778 - val_binary_accuracy: 0.9782
# Epoch 80/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0695 - binary_accuracy: 0.9695 - val_loss: 0.0827 - val_binary_accuracy: 0.9802
# Epoch 81/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0697 - binary_accuracy: 0.9694 - val_loss: 0.0721 - val_binary_accuracy: 0.9754
# Epoch 82/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0692 - binary_accuracy: 0.9699 - val_loss: 0.0933 - val_binary_accuracy: 0.9828
# Epoch 83/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0692 - binary_accuracy: 0.9698 - val_loss: 0.0703 - val_binary_accuracy: 0.9722
# Epoch 84/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0686 - binary_accuracy: 0.9701 - val_loss: 0.0675 - val_binary_accuracy: 0.9727
# Epoch 85/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0683 - binary_accuracy: 0.9705 - val_loss: 0.0734 - val_binary_accuracy: 0.9775
# Epoch 86/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0683 - binary_accuracy: 0.9704 - val_loss: 0.0734 - val_binary_accuracy: 0.9759
# Epoch 87/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0681 - binary_accuracy: 0.9708 - val_loss: 0.0708 - val_binary_accuracy: 0.9762
# Epoch 88/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0683 - binary_accuracy: 0.9707 - val_loss: 0.0811 - val_binary_accuracy: 0.9819
# Epoch 89/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0678 - binary_accuracy: 0.9707 - val_loss: 0.0710 - val_binary_accuracy: 0.9749
# Epoch 90/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0670 - binary_accuracy: 0.9721 - val_loss: 0.0812 - val_binary_accuracy: 0.9816
# Epoch 91/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0671 - binary_accuracy: 0.9719 - val_loss: 0.0791 - val_binary_accuracy: 0.9820
# Epoch 92/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0672 - binary_accuracy: 0.9718 - val_loss: 0.0681 - val_binary_accuracy: 0.9684
# Epoch 93/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0670 - binary_accuracy: 0.9717 - val_loss: 0.0682 - val_binary_accuracy: 0.9712
# Epoch 94/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0666 - binary_accuracy: 0.9723 - val_loss: 0.0787 - val_binary_accuracy: 0.9791
# Epoch 95/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0670 - binary_accuracy: 0.9720 - val_loss: 0.0688 - val_binary_accuracy: 0.9723
# Epoch 96/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0665 - binary_accuracy: 0.9722 - val_loss: 0.0683 - val_binary_accuracy: 0.9714
# Epoch 97/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0658 - binary_accuracy: 0.9730 - val_loss: 0.0724 - val_binary_accuracy: 0.9786
# Epoch 98/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0657 - binary_accuracy: 0.9730 - val_loss: 0.0768 - val_binary_accuracy: 0.9799
# Epoch 99/100
# 1704/1704 [==============================] - 938s 551ms/step - loss: 0.0657 - binary_accuracy: 0.9730 - val_loss: 0.0681 - val_binary_accuracy: 0.9753
# Epoch 100/100
# 1704/1704 [==============================] - 947s 556ms/step - loss: 0.0655 - binary_accuracy: 0.9733 - val_loss: 0.0696 - val_binary_accuracy: 0.9741
# 1553993485.9948285
# 94193.52350616455
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="http://www.kozco.com/tech/piano2.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
model.save('excldCV5-data/'+datestring+'_excldCV5-MADplot-800Epochs.h')

# %%
testIdx = 72
testImage = x_val[testIdx:testIdx+1,:,:,:]

yhat = model.predict(testImage)

plt.imshow(x_val[testIdx,:,:,0].T, cmap='gray')
plt.figure()
plt.imshow(yhat[0,:,:,0].T)
plt.figure()
plt.imshow(y_val[testIdx,:,:,0].T)

# %% [markdown]
# # Save history

# %%
for key in hist.history:
    print (key)

# %%
bin_acc = hist.history['binary_accuracy']
val_bin_acc = hist.history['val_binary_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs =  range(1, len(bin_acc)+1)

plt.plot(epochs, bin_acc, 'bo', label='Training')
plt.plot(epochs, val_bin_acc, 'b', label='Validation')
plt.title('Training and validation binary accuracy')

plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training')
plt.plot(epochs, val_loss, 'b', label='Validation')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import pickle

datestring = date.today().strftime("%y%m%d")
filename = "excldCV5-data/"+datestring+"_MADplot_AdvUNETS_history.p"
outfile = open(filename, 'wb')

pickle.dump(hist.history, outfile)
outfile.close()

# %% [markdown]
# test pickle file

# %%
outfile = open(filename, 'rb')
myhist = pickle.load(outfile)

# %%
datGen = my_generator(x_val, y_val, 4)

for i in range(17):
    test_batch, test_mask_batch = next(datGen)

yhat = model.predict(test_batch)

fix, ax = plt.subplots(4,3, figsize=(12,25))
for i in range(4):
    ax[i,0].imshow(test_batch[i,:,:,0].T)
    ax[i,1].imshow(test_mask_batch[i,:,:,0].T)
    ax[i,2].imshow(yhat[i,:,:,0].T>0.5)
plt.show()

# %%
model.save('MADplot-AdvUNETS-Data/'+datestring+'_MADplot_UNETS.h5')

# %%
#model.save('MADplot-AdvUNETS-Data/liverSegUNETS_1.h5')
